# %%
import pandas as pd

# %%
df = pd.read_excel('temp.xlsx')

# %%
df
# Out:
#    name  age    sal
# 0   xyh   56  15687
# 1  bfjd   53  36584
# 2   nkd   24   2535

# %%
df[['age']]
# Out:
#    age
# 0   56
# 1   53
# 2   24

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is EE22-D61B
#
#  Directory of C:\Users\kunal\OneDrive\Desktop\ml
#
# 28-10-2022  17:07    <DIR>          .
# 28-10-2022  11:34    <DIR>          ..
# 28-10-2022  17:01    <DIR>          .ipynb_checkpoints
# 28-10-2022  16:58            17,009 pandas 1.ipynb
# 28-10-2022  12:44               577 temp.html
# 28-10-2022  11:53             9,459 temp.xlsx
# 28-10-2022  11:37                55 test.txt
# 28-10-2022  17:07             4,085 Untitled.ipynb
#                5 File(s)         31,185 bytes
#                3 Dir(s)  351,373,537,280 bytes free

# %%
df.shape
# Out:
# (3, 3)

# %%
df1=pd.read_excel('data.xlsx')

# %%
df1
# Out:
#    Unnamed: 0                                Unnamed: 1     Unnamed: 2  \
# 0         NaN                                       NaN            NaN
# 1       SL no                               Description         Cat no
# 2           1           280/70R16 GX Garden Pro  112 TL      579755-36
# 3           2          230/95R48(9.5R48) AL 350  136 TL  35050030AL-IG
# 4           3         800/40-26.5 644 FORESTAR III 20TT  64400090AL-IG
# 5           4             23.1-26 AL FP 324 16 159A8 TL  32467333FP-IG
# 6           5             500/60-22.5 328 Value + 16 TL  32828108VP-IG
# 7           6                         17.5-25 318 16 TL  31800899AL-IG
# 8           7                     17.5-25 LHD-500 20 TL      368459-36
# 9           8                      17.5-25 EXR300 24 TL      344217-36
# 10          9                  14.00-24 MPC G2-L2 12 TL      287411-36
# 11         10                      20.5-25 EXR300 20 TL      344469-36
# ...
